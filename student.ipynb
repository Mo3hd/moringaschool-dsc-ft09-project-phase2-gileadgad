# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# ### Gilead Gad
# ### DSF-FT09 Hybrid
# ### Scheduled date:
# ### TM - Antonny Muiko

# %%
# Your code here - remember to use markdown cells for comments as well!
# importing all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib.ticker as ticker

# %%
# Opening the csv file in the zipped folder
first_dataset = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
first_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# Having a look at the first five rows of the dataset

first_dataset.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Loading second dataset
second_dataset = pd.read_csv('zippedData/rt.movie_info.tsv.gz', error_bad_lines=False)
display(second_dataset.head())
display(second_dataset.info())
# Out:
# b'Skipping line 7: expected 25 fields, saw 28\nSkipping line 58: expected 25 fields, saw 26\nSkipping line 60: expected 25 fields, saw 36\nSkipping line 95: expected 25 fields, saw 34\nSkipping line 161: expected 25 fields, saw 32\nSkipping line 235: expected 25 fields, saw 27\nSkipping line 326: expected 25 fields, saw 30\nSkipping line 425: expected 25 fields, saw 26\nSkipping line 476: expected 25 fields, saw 34\nSkipping line 497: expected 25 fields, saw 38\nSkipping line 504: expected 25 fields, saw 29\nSkipping line 526: expected 25 fields, saw 30\nSkipping line 535: expected 25 fields, saw 27\nSkipping line 554: expected 25 fields, saw 27\nSkipping line 562: expected 25 fields, saw 31\nSkipping line 581: expected 25 fields, saw 40\nSkipping line 725: expected 25 fields, saw 36\nSkipping line 858: expected 25 fields, saw 27\nSkipping line 880: expected 25 fields, saw 30\nSkipping line 970: expected 25 fields, saw 26\nSkipping line 997: expected 25 fields, saw 49\nSkipping line 1037: expected 25 fields, saw 26\nSkipping line 1038: expected 25 fields, saw 30\nSkipping line 1051: expected 25 fields, saw 27\nSkipping line 1167: expected 25 fields, saw 26\nSkipping line 1174: expected 25 fields, saw 28\nSkipping line 1195: expected 25 fields, saw 27\nSkipping line 1338: expected 25 fields, saw 27\nSkipping line 1372: expected 25 fields, saw 29\nSkipping line 1396: expected 25 fields, saw 41\nSkipping line 1408: expected 25 fields, saw 27\nSkipping line 1431: expected 25 fields, saw 27\nSkipping line 1541: expected 25 fields, saw 32\n'
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          id\tsynopsis\trating\tgenre\tdirector\twriter\ttheater_date\tdvd_date\tcurrency\tbox_office\truntime\tstudio
# 1\t"This gritty                                     fast-paced                                         and innovative police drama earned five Academ...  including Best Picture                             Best Adapted Screenplay (written by Ernest Tid...  and Best Actor (Gene Hackman). Jimmy ""Popeye"...  Buddy Russo (Roy Scheider)                         are New York City police detectives on narcoti...  trying to track down the source of heroin from...  and Pierre Nicoli (Marcel Bozzuffi) is a hired...  Popeye and Buddy start tailing Sal Boca (Tony ...  Angie (Arlene Faber)                               who live pretty high for a couple whose corner... 000 dollars a year. It turns out Popeye's suspi...  who will be smuggling 32 million dollars' wort...  an often violent                                   racist                                             and mean-spirited cop whose dedication to his ...  a high-speed car chase with Popeye tailing an ...  was one of the most viscerally exciting screen...  and Eddie Egan and Sonny Grosso  Popeye and Buddy's real life counterparts  both have small roles in the film. A sequel fo...  1971\tSep 25                            2001\t\t\t104 minutes\t
# 3\tNew York City                                    not-too-distant-future: Eric Packer                a 28 year-old finance golden boy dreaming of l...  watches a dark shadow cast over the firmament ...  of which he is the uncontested king. As he is ...  his anxious eyes are glued to the yuan's excha...  destroying Eric's bet against it. Eric Packer ...  an eruption of wild activity unfolds in the ci...  his paranoia intensifies during the course of ...  2012\tJan 1                                        2013\t$\t600                                      000\t108 minutes\tEntertainment One                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                              NaN                                        NaN                                                NaN                                                          NaN
# 5\t"Illeana Douglas delivers a superb performan...  a fictional singer and songwriter whose life b...  the daughter of a Philadelphia steel tycoon        aspires to a career as a singer                    and when against her mother's bidding she sing...  ""You'll Never Walk Alone"") at a talent contest   she wins a recording contact and moves to New ...  Denise Waverly; however                            she soon finds that girl singers are a dime a ...  and eccentric producer Joel Milner (John Turtu...  a hipster songwriter who wants to express his ...  she finds both a successful collaborator and h...  their marriage falls apart                         and she becomes involved with Jay Phillips (Ma...  the gifted but unstable leader of a popular We...  and the 1960s-style song score includes number...  as well as one-time King collaborator Gerry Go...  ""God Give Me Strength                             led to a full album written by the two great t...  1996\tApr 18                                       2000\t\t\t116 minutes\t         NaN                                        NaN                                                NaN                                                          NaN
# 6\tMichael Douglas runs afoul of a treacherous ...  an executive at DigiCom                            a leading computer software firm. DigiCom is a...  and Bob Garvin (Donald Sutherland)                 the owner of the company                           is in the midst of negotiating a merger that c...  1994\tAug 27                                       1997\t\t\t128 minutes\t                           NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                              NaN                                        NaN                                                NaN                                                          NaN
# 7\t\tNR\tDrama|Romance\tRodney Bennett\tGiles C... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                              NaN                                        NaN                                                NaN                                                          NaN
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1525 entries, ('1\t"This gritty', ' fast-paced', ' and innovative police drama earned five Academy Awards', ' including Best Picture', ' Best Adapted Screenplay (written by Ernest Tidyman)', ' and Best Actor (Gene Hackman). Jimmy ""Popeye"" Doyle (Hackman) and his partner', ' Buddy Russo (Roy Scheider)', ' are New York City police detectives on narcotics detail', " trying to track down the source of heroin from Europe into the United States. Suave Alain Charnier (Fernando Rey) is the French drug kingpin who provides a large percentage of New York City's dope", " and Pierre Nicoli (Marcel Bozzuffi) is a hired killer and Charnier's right-hand man. Acting on a hunch", ' Popeye and Buddy start tailing Sal Boca (Tony Lo Bianco) and his wife', ' Angie (Arlene Faber)', ' who live pretty high for a couple whose corner store brings in about 7', "000 dollars a year. It turns out Popeye's suspicions are right -- Sal and Angie are the New York agents for Charnier", ' who will be smuggling 32 million dollars\' worth of heroin into the city in a car shipped over from France. The French Connection broke plenty of new ground for screen thrillers; Popeye Doyle was a highly unusual ""hero', ' an often violent', ' racist', " and mean-spirited cop whose dedication to his job fell just short of dangerous obsession. The film's high point", ' a high-speed car chase with Popeye tailing an elevated train', " was one of the most viscerally exciting screen moments of its day and set the stage for dozens of action sequences to follow. And the film's grimy realism (and downbeat ending) was a big change from the buff-and-shine gloss and good-guys-always-win heroics of most police dramas that preceded it. The French Connection was inspired by a true story", ' and Eddie Egan and Sonny Grosso', " Popeye and Buddy's real life counterparts", ' both have small roles in the film. A sequel followed four years later."\tR\tAction and Adventure|Classics|Drama\tWilliam Friedkin\tErnest Tidyman\tOct 9', ' 1971\tSep 25') to ('2000\tSuspended from the force', ' Paris cop Hubert is summoned to Tokyo when his former lover Miko dies. Upon arriving', " Hubert discovers he is to be the legal guardian for Miko's teen daughter Yumi. As Hubert begins to investigate the circumstances surrounding Miko's mysterious death", ' he grows closer to Yumi.\tR\tAction and Adventure|Art House and International|Comedy|Drama|Mystery and Suspense\t\tLuc Besson\tSep 27', ' 2001\tFeb 11', ' 2003\t\t\t94 minutes\tColumbia Pictures', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   id	synopsis	rating	genre	director	writer	theater_date	dvd_date	currency	box_office	runtime	studio  6 non-null      object
# dtypes: object(1)
# memory usage: 608.9+ KB
# None

# %%
third_dataset = pd.read_csv('zippedData/rt.reviews.tsv.gz', error_bad_lines=False)
display(third_dataset.head())
display(third_dataset.info())
# Out:
# b'Skipping line 5: expected 3 fields, saw 5\nSkipping line 7: expected 3 fields, saw 5\nSkipping line 8: expected 3 fields, saw 4\nSkipping line 10: expected 3 fields, saw 4\nSkipping line 11: expected 3 fields, saw 4\nSkipping line 12: expected 3 fields, saw 4\nSkipping line 15: expected 3 fields, saw 4\nSkipping line 17: expected 3 fields, saw 4\nSkipping line 20: expected 3 fields, saw 4\nSkipping line 21: expected 3 fields, saw 4\nSkipping line 23: expected 3 fields, saw 5\nSkipping line 24: expected 3 fields, saw 4\nSkipping line 26: expected 3 fields, saw 4\nSkipping line 29: expected 3 fields, saw 5\nSkipping line 36: expected 3 fields, saw 4\nSkipping line 37: expected 3 fields, saw 4\nSkipping line 53: expected 3 fields, saw 4\nSkipping line 54: expected 3 fields, saw 4\nSkipping line 55: expected 3 fields, saw 5\nSkipping line 57: expected 3 fields, saw 5\nSkipping line 58: expected 3 fields, saw 7\nSkipping line 59: expected 3 fields, saw 6\nSkipping line 60: expected 3 fields, saw 4\nSkipping line 73: expected 3 fields, saw 6\nSkipping line 74: expected 3 fields, saw 4\nSkipping line 75: expected 3 fields, saw 4\nSkipping line 77: expected 3 fields, saw 5\nSkipping line 79: expected 3 fields, saw 5\nSkipping line 82: expected 3 fields, saw 5\nSkipping line 86: expected 3 fields, saw 5\nSkipping line 98: expected 3 fields, saw 5\nSkipping line 99: expected 3 fields, saw 4\nSkipping line 107: expected 3 fields, saw 4\nSkipping line 108: expected 3 fields, saw 4\nSkipping line 109: expected 3 fields, saw 4\nSkipping line 110: expected 3 fields, saw 4\nSkipping line 113: expected 3 fields, saw 5\nSkipping line 115: expected 3 fields, saw 8\nSkipping line 117: expected 3 fields, saw 6\nSkipping line 119: expected 3 fields, saw 4\nSkipping line 124: expected 3 fields, saw 4\nSkipping line 126: expected 3 fields, saw 4\nSkipping line 128: expected 3 fields, saw 4\nSkipping line 129: expected 3 fields, saw 4\nSkipping line 132: expected 3 fields, saw 4\nSkipping line 133: expected 3 fields, saw 5\nSkipping line 135: expected 3 fields, saw 4\nSkipping line 136: expected 3 fields, saw 4\nSkipping line 137: expected 3 fields, saw 4\nSkipping line 138: expected 3 fields, saw 4\nSkipping line 139: expected 3 fields, saw 4\nSkipping line 140: expected 3 fields, saw 4\nSkipping line 146: expected 3 fields, saw 4\nSkipping line 149: expected 3 fields, saw 4\nSkipping line 150: expected 3 fields, saw 5\nSkipping line 152: expected 3 fields, saw 5\nSkipping line 153: expected 3 fields, saw 5\nSkipping line 156: expected 3 fields, saw 5\nSkipping line 157: expected 3 fields, saw 6\nSkipping line 161: expected 3 fields, saw 6\nSkipping line 165: expected 3 fields, saw 4\nSkipping line 167: expected 3 fields, saw 5\nSkipping line 191: expected 3 fields, saw 5\nSkipping line 192: expected 3 fields, saw 5\nSkipping line 193: expected 3 fields, saw 4\nSkipping line 197: expected 3 fields, saw 5\nSkipping line 198: expected 3 fields, saw 4\nSkipping line 202: expected 3 fields, saw 4\nSkipping line 204: expected 3 fields, saw 4\nSkipping line 207: expected 3 fields, saw 4\nSkipping line 208: expected 3 fields, saw 4\nSkipping line 211: expected 3 fields, saw 4\nSkipping line 214: expected 3 fields, saw 6\nSkipping line 224: expected 3 fields, saw 4\nSkipping line 227: expected 3 fields, saw 4\nSkipping line 228: expected 3 fields, saw 4\nSkipping line 234: expected 3 fields, saw 4\nSkipping line 246: expected 3 fields, saw 6\nSkipping line 263: expected 3 fields, saw 5\nSkipping line 276: expected 3 fields, saw 4\nSkipping line 283: expected 3 fields, saw 4\nSkipping line 285: expected 3 fields, saw 4\nSkipping line 286: expected 3 fields, saw 4\nSkipping line 300: expected 3 fields, saw 6\nSkipping line 331: expected 3 fields, saw 4\nSkipping line 332: expected 3 fields, saw 4\nSkipping line 333: expected 3 fields, saw 4\nSkipping line 336: expected 3 fields, saw 4\nSkipping line 338: expected 3 fields, saw 4\nSkipping line 339: expected  ...
#                                                                                                        id\treview\trating\tfresh\tcritic\ttop_critic\tpublisher\tdate
# 3\tA distinctly gallows take on contemporary fi...  as one absurdly rich man's limo ride across to...                                             2018.0
# 3\tIt's an allegory in search of a meaning that...  2018                                                                                             NaN
# 3\t... life lived in a bubble in financial deal...  2018                                                                                             NaN
# 3\t... a perverse twist on neorealism... \t\tfr...  2017                                                                                             NaN
# 3\tCronenberg is not a director to be daunted b...  2013                                                                                             NaN
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 40195 entries, ('3\tA distinctly gallows take on contemporary financial mores', " as one absurdly rich man's limo ride across town for a haircut functions as a state-of-the-nation discourse. \t3/5\tfresh\tPJ Nabarro\t0\tPatrick Nabarro\tNovember 10") to ('2000\t\t3/5\tfresh\tNicolas Lacroix\t0\tShowbizz.net\tNovember 12', ' 2002')
# Data columns (total 1 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   id	review	rating	fresh	critic	top_critic	publisher	date  17184 non-null  float64
# dtypes: float64(1)
# memory usage: 2.8+ MB
# None

# %%
fourth_dataset  = pd.read_csv('zippedData/tmdb.movies.csv.gz')
display(fourth_dataset.head())
display(fourth_dataset.info())
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None

# %%
fifth_dataset  = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
display(fifth_dataset.head())
display(fifth_dataset.info())
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None

# %% [markdown]
# #### Data Cleaning

# %%
# Extracting domestic gross and worldwide gross columns from the sixth dataset
df = fifth_dataset[['domestic_gross', 'worldwide_gross']]
df
# Out:
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 2 columns]

# %% [markdown]
# ##### Data Cleaning im domestic_gross column
# ##### Objectives
#  Removing the $ sign, the commas  between values and converting the value to int type from being a str type

# %%
# Removing the money sign 
result_1 = fifth_dataset['domestic_gross'].str.replace('$','')
result_1
# Out:
# 0       760,507,625
# 1       241,063,875
# 2        42,762,350
# 3       459,005,868
# 4       620,181,382
#            ...
# 5777              0
# 5778         48,482
# 5779          1,338
# 5780              0
# 5781        181,041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
# Removing the commas between the values
result_2 = result_1.str.replace(',', '')
result_2
# Out:
# 0       760507625
# 1       241063875
# 2        42762350
# 3       459005868
# 4       620181382
#           ...
# 5777            0
# 5778        48482
# 5779         1338
# 5780            0
# 5781       181041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
# Converting the values into int type from str
result_3 = result_2.astype(int)
result_3
# Out:
# 0       760507625
# 1       241063875
# 2        42762350
# 3       459005868
# 4       620181382
#           ...
# 5777            0
# 5778        48482
# 5779         1338
# 5780            0
# 5781       181041
# Name: domestic_gross, Length: 5782, dtype: int64

# %%
result_4 = np.where(result_3 > 100000)
result_4
# Out:
# (array([   0,    1,    2, ..., 5773, 5774, 5781]),)

# %%
df_result = np.where(fifth_dataset['domestic_gross'] > fifth_dataset['worldwide_gross'])
df_result
# Out:
# (array([   0,    1,    2, ..., 5643, 5656, 5778]),)

# %% [markdown]
# ### Summary
# Project will consider these datasets: <b>'tn.movie_budgets.csv.gz'</b> and <b>'tmdb.movies.csv.gz'</b> and <b>'imdb.title.basics.csv.gz'</b><br>
# <br>
# The bottom line for the "success" of a film is the money it makes (Revenue).<br>
# Variables that may influence the <b>"success"</b> of a film:<br>
# <br>
# Domestic Gross Revenue<br>
# Worldwide Gross Revenue<br>
# Average Vote Rating<br>
# Vote Count<br>
# Popularity<br>
# Release Date<br>
# Film Title<br>
# Genre<br>

# %% [markdown]
# <b>Data cleaning for fifth_dataset"release_date"</b><br>
# Convert str to datetime object to parse out the "month" in later analysis.<br>

# %%
# Convert release date into date time object
fifth_dataset['release_date'] =  pd.to_datetime(fifth_dataset['release_date'], infer_datetime_format=True)
fifth_dataset.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# #### Read Selected CSVs To Dataframes
# Load 3 selected CSVs to bring data into Jupyter Notebook.<br>
# Show .head() and .info() for all imported dataframes to get a feel for the data.

# %%
df_imdb = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
display(df_imdb.head())
display(df_imdb.info())
fifth_dataset  = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
display(fifth_dataset.head())
display(fifth_dataset.info())
fourth_dataset  = pd.read_csv('zippedData/tmdb.movies.csv.gz')
display(fourth_dataset.head())
display(fourth_dataset.info())
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# <b>Data cleaning to eliminate unused columns of data</b><br>
# We will get rid of columns of data that we are not considering in our analysis.

# %%
df_imdb_edit = df_imdb.drop(['tconst','original_title','start_year','runtime_minutes'], axis =1)
df_tn_edit = fifth_dataset.drop(['id','domestic_gross'], axis =1)
df_tmdb_edit = fourth_dataset.drop(['Unnamed: 0','genre_ids','id','original_title'], axis =1)
#drop release_date from "df_tmdb_edit" since we already have a "release_date" in "df_tn_edit"
df_tmdb_edit = df_tmdb_edit.drop('release_date', axis=1)

display(df_imdb_edit.head())
display(df_tmdb_edit.head())
display(df_tn_edit.head())
# Out:
#                      primary_title                genres
# 0                        Sunghursh    Action,Crime,Drama
# 1  One Day Before the Rainy Season       Biography,Drama
# 2       The Other Side of the Wind                 Drama
# 3                  Sabse Bada Sukh          Comedy,Drama
# 4         The Wandering Soap Opera  Comedy,Drama,Fantasy
#   original_language  popularity                                         title  \
# 0                en      33.533  Harry Potter and the Deathly Hallows: Part 1
# 1                en      28.734                      How to Train Your Dragon
# 2                en      28.515                                    Iron Man 2
# 3                en      28.005                                     Toy Story
# 4                en      27.920                                     Inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget worldwide_gross
# 0      $425,000,000  $2,776,345,279
# 1      $410,600,000  $1,045,663,875
# 2      $350,000,000    $149,762,350
# 3      $330,600,000  $1,403,013,963
# 4      $317,000,000  $1,316,721,747

# %% [markdown]
# <b>Data cleaning to eliminate duplicate rows</b><br>
# We will get rid of any duplicate rows in our dataset.

# %%
#eliminate any duplicates in df_imdb_edit and reassign.
df_imdb_edit = df_imdb_edit.drop_duplicates(subset=None, keep='first')
display(df_imdb_edit)
#eliminate any duplicates in df_tn_edit and reassign.
df_tn_edit = df_tn_edit.drop_duplicates(subset=None, keep='first')
display(df_tn_edit)
#eliminate any duplicates in df_tn_edit and reassign.
df_tmdb_edit = df_tmdb_edit.drop_duplicates(subset=None, keep='first')
display(df_tmdb_edit)
# Out:
#                                       primary_title                genres
# 0                                         Sunghursh    Action,Crime,Drama
# 1                   One Day Before the Rainy Season       Biography,Drama
# 2                        The Other Side of the Wind                 Drama
# 3                                   Sabse Bada Sukh          Comedy,Drama
# 4                          The Wandering Soap Opera  Comedy,Drama,Fantasy
# ...                                             ...                   ...
# 146139                          Kuambil Lagi Hatiku                 Drama
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro           Documentary
# 146141                              Dankyavar Danka                Comedy
# 146142                                       6 Gunn                   NaN
# 146143               Chico Albuquerque - Revelações           Documentary
#
# [144479 rows x 2 columns]
#       release_date                                        movie  \
# 0     Dec 18, 2009                                       Avatar
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      Jun 7, 2019                                 Dark Phoenix
# 3      May 1, 2015                      Avengers: Age of Ultron
# 4     Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...            ...                                          ...
# 5777  Dec 31, 2018                                       Red 11
# 5778   Apr 2, 1999                                    Following
# 5779  Jul 13, 2005                Return to the Land of Wonders
# 5780  Sep 29, 2015                         A Plague So Pleasant
# 5781   Aug 5, 2005                            My Date With Drew
#
#      production_budget worldwide_gross
# 0         $425,000,000  $2,776,345,279
# 1         $410,600,000  $1,045,663,875
# 2         $350,000,000    $149,762,350
# 3         $330,600,000  $1,403,013,963
# 4         $317,000,000  $1,316,721,747
# ...                ...             ...
# 5777            $7,000              $0
# 5778            $6,000        $240,495
# 5779            $5,000          $1,338
# 5780            $1,400              $0
# 5781            $1,100        $181,041
#
# [5782 rows x 4 columns]
#       original_language  popularity  \
# 0                    en      33.533
# 1                    en      28.734
# 2                    en      28.515
# 3                    en      28.005
# 4                    en      27.920
# ...                 ...         ...
# 26512                en       0.600
# 26513                en       0.600
# 26514                en       0.600
# 26515                en       0.600
# 26516                en       0.600
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [25493 rows x 5 columns]

# %% [markdown]
# <b>Data cleaning to eliminate NaN values</b><br>
# We will check for, and get rid of any NaN values in our dataset.

# %%
# check to see how many "NaN" values in df_imdb_edit
display(df_imdb_edit.isna().sum())
# drop the Nan rows 
df_imdb_edit = df_imdb_edit.dropna()
# check to see how many "NaN" values in df_tn_edit - NONE. No .dropna() needed.
display(df_tn_edit.isna().sum())
# check for 'Nan' values in df_tmdb)edit - NONE. No .dropna() needed.
display(df_tmdb_edit.isna().sum())
# Out:
# primary_title       0
# genres           5355
# dtype: int64
# release_date         0
# movie                0
# production_budget    0
# worldwide_gross      0
# dtype: int64
# original_language    0
# popularity           0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %% [markdown]
# <b>Data cleaning to prepare for merge</b><br>
# We will change "primary_title" in df_imdb_edit and "title" in df_tmdb_edit to "movie" to match df_tn_edit, and make the "movie" column name consistent across the 3 data sets

# %%
#We will change "primary_title" in df_imdb_edit and "title" in df_tmdb_edit to "movie" to match df_tn_edit, and make the "movie" column name consistent across the 3 data sets
df_imdb_edit = df_imdb_edit.rename(columns = {"primary_title": "movie"})
df_tmdb_edit = df_tmdb_edit.rename(columns = {"title": "movie"})

display(df_imdb_edit.head())
display(df_tmdb_edit.head())
display(df_tn_edit.head())
# Out:
#                              movie                genres
# 0                        Sunghursh    Action,Crime,Drama
# 1  One Day Before the Rainy Season       Biography,Drama
# 2       The Other Side of the Wind                 Drama
# 3                  Sabse Bada Sukh          Comedy,Drama
# 4         The Wandering Soap Opera  Comedy,Drama,Fantasy
#   original_language  popularity                                         movie  \
# 0                en      33.533  Harry Potter and the Deathly Hallows: Part 1
# 1                en      28.734                      How to Train Your Dragon
# 2                en      28.515                                    Iron Man 2
# 3                en      28.005                                     Toy Story
# 4                en      27.920                                     Inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget worldwide_gross
# 0      $425,000,000  $2,776,345,279
# 1      $410,600,000  $1,045,663,875
# 2      $350,000,000    $149,762,350
# 3      $330,600,000  $1,403,013,963
# 4      $317,000,000  $1,316,721,747

# %% [markdown]
# ### Merging
# <b>Inner merge all datasets</b><br>
# We will inner merge all 3 datasets on 'movie' column, because we want all rows to have data populated on movies that they all have in common.

# %%
#inner merge all 3 datasets on 'movie' column
df_merged = df_tmdb_edit.merge(df_tn_edit, on='movie').merge(df_imdb_edit, on='movie')
df_merged.head()
# Out:
#   original_language  popularity  \
# 0                en      28.734
# 1                en      28.515
# 2                en      27.920
# 3                en      26.691
# 4                en      26.526
#
#                                                movie  vote_average  \
# 0                           How to Train Your Dragon           7.7
# 1                                         Iron Man 2           6.8
# 2                                          Inception           8.3
# 3  Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                             Avatar           7.4
#
#    vote_count  release_date production_budget worldwide_gross  \
# 0        7610  Mar 26, 2010      $165,000,000    $494,870,992
# 1       12368   May 7, 2010      $170,000,000    $621,156,389
# 2       22186  Jul 16, 2010      $160,000,000    $835,524,642
# 3        4229  Feb 12, 2010       $95,000,000    $223,050,874
# 4       18676  Dec 18, 2009      $425,000,000  $2,776,345,279
#
#                        genres
# 0  Action,Adventure,Animation
# 1     Action,Adventure,Sci-Fi
# 2     Action,Adventure,Sci-Fi
# 3    Adventure,Family,Fantasy
# 4                      Horror

# %% [markdown]
# #### Sorting
# We will sort the movies so as to use them as indeces

# %%
#sort dataframe by movies alphabetically
df_merged = df_merged.sort_values(by='movie', ascending=True)
df_merged.head()
# Out:
#      original_language  popularity                  movie  vote_average  \
# 2873                de       6.099                #Horror           3.3
# 3072                en      17.892    10 Cloverfield Lane           6.9
# 2991                en       0.955  10 Days in a Madhouse           5.4
# 3636                en      13.183              12 Strong           5.6
# 1808                en      16.493       12 Years a Slave           7.9
#
#       vote_count  release_date production_budget worldwide_gross  \
# 2873         102  Nov 20, 2015        $1,500,000              $0
# 3072        4629  Mar 11, 2016        $5,000,000    $108,286,422
# 2991           7  Nov 11, 2015       $12,000,000         $14,616
# 3636        1312  Jan 19, 2018       $35,000,000     $71,118,378
# 1808        6631  Oct 18, 2013       $20,000,000    $181,025,343
#
#                        genres
# 2873       Crime,Drama,Horror
# 3072     Drama,Horror,Mystery
# 2991                    Drama
# 3636     Action,Drama,History
# 1808  Biography,Drama,History

# %% [markdown]
# #### Post merge cleanup

# %%
#run groupby and take only the first instance of each movie group
df_gp_movie = df_merged.groupby('movie')
df_gp_movie.first()
#reassign back to a dataframe object
df_merged_movie = df_gp_movie.first()
df_merged_movie
# Out:
#                            original_language  popularity  vote_average  \
# movie
# #Horror                                   de       6.099           3.3
# 10 Cloverfield Lane                       en      17.892           6.9
# 10 Days in a Madhouse                     en       0.955           5.4
# 12 Strong                                 en      13.183           5.6
# 12 Years a Slave                          en      16.493           7.9
# ...                                      ...         ...           ...
# Zookeeper                                 en      10.764           5.3
# Zoolander 2                               en      12.997           4.7
# Zoom                                      en       3.434           5.5
# Zootopia                                  en      27.549           7.7
# xXx: Return of Xander Cage                en      21.749           5.6
#
#                             vote_count  release_date production_budget  \
# movie
# #Horror                            102  Nov 20, 2015        $1,500,000
# 10 Cloverfield Lane               4629  Mar 11, 2016        $5,000,000
# 10 Days in a Madhouse                7  Nov 11, 2015       $12,000,000
# 12 Strong                         1312  Jan 19, 2018       $35,000,000
# 12 Years a Slave                  6631  Oct 18, 2013       $20,000,000
# ...                                ...           ...               ...
# Zookeeper                          886   Jul 8, 2011       $80,000,000
# Zoolander 2                       1374  Feb 12, 2016       $50,000,000
# Zoom                                43  Aug 11, 2006       $35,000,000
# Zootopia                          9977   Mar 4, 2016      $150,000,000
# xXx: Return of Xander Cage        2452  Jan 20, 2017       $85,000,000
#
#                            worldwide_gross                      genres
# movie
# #Horror                                 $0          Crime,Drama,Horror
# 10 Cloverfield Lane           $108,286,422        Drama,Horror,Mystery
# 10 Days in a Madhouse              $14,616                       Drama
# 12 Strong                      $71,118,378        Action,Drama,History
# 12 Years a Slave              $181,025,343     Biography,Drama,History
# ...                                    ...                         ...
# Zookeeper                     $170,805,525       Comedy,Family,Romance
# Zoolander 2                    $55,348,693                      Comedy
# Zoom                           $12,506,188                      Horror
# Zootopia                    $1,019,429,616  Adventure,Animation,Comedy
# xXx: Return of Xander Cage    $345,033,359   Action,Adventure,Thriller
#
# [1788 rows x 8 columns]

# %% [markdown]
# ##### Some movies have more than one genre so we are putting them under one genre called mix

# %%
df_merged_movie.loc[df_merged_movie['genres'].str.contains(','), 'genres'] = 'mix'
df_merged_movie.head()
# Out:
#                       original_language  popularity  vote_average  vote_count  \
# movie
# #Horror                              de       6.099           3.3         102
# 10 Cloverfield Lane                  en      17.892           6.9        4629
# 10 Days in a Madhouse                en       0.955           5.4           7
# 12 Strong                            en      13.183           5.6        1312
# 12 Years a Slave                     en      16.493           7.9        6631
#
#                        release_date production_budget worldwide_gross genres
# movie
# #Horror                Nov 20, 2015        $1,500,000              $0    mix
# 10 Cloverfield Lane    Mar 11, 2016        $5,000,000    $108,286,422    mix
# 10 Days in a Madhouse  Nov 11, 2015       $12,000,000         $14,616  Drama
# 12 Strong              Jan 19, 2018       $35,000,000     $71,118,378    mix
# 12 Years a Slave       Oct 18, 2013       $20,000,000    $181,025,343    mix

# %% [markdown]
# <b>Adding "release_month" data</b><br>
# We are particularly interested in movie release by month - so we will create a new column named "release_month"

# %%
# creating a new column called release month
df_merged_movie['release_month'] = pd.DatetimeIndex(df_merged_movie['release_date']).month
df_merged_movie.head()
# Out:
#                       original_language  popularity  vote_average  vote_count  \
# movie
# #Horror                              de       6.099           3.3         102
# 10 Cloverfield Lane                  en      17.892           6.9        4629
# 10 Days in a Madhouse                en       0.955           5.4           7
# 12 Strong                            en      13.183           5.6        1312
# 12 Years a Slave                     en      16.493           7.9        6631
#
#                        release_date production_budget worldwide_gross genres  \
# movie
# #Horror                Nov 20, 2015        $1,500,000              $0    mix
# 10 Cloverfield Lane    Mar 11, 2016        $5,000,000    $108,286,422    mix
# 10 Days in a Madhouse  Nov 11, 2015       $12,000,000         $14,616  Drama
# 12 Strong              Jan 19, 2018       $35,000,000     $71,118,378    mix
# 12 Years a Slave       Oct 18, 2013       $20,000,000    $181,025,343    mix
#
#                        release_month
# movie
# #Horror                           11
# 10 Cloverfield Lane                3
# 10 Days in a Madhouse             11
# 12 Strong                          1
# 12 Years a Slave                  10

# %%
# Remove the dollar sign and commas, then convert to integer type for 'worldwide_gross' and 'production_budget' columns
df_merged_movie['worldwide_gross'] = df_merged_movie['worldwide_gross'].str.replace('[$,]', '').astype(int)
df_merged_movie['production_budget'] = df_merged_movie['production_budget'].str.replace('[$,]', '').astype(int)

df_merged_movie[['worldwide_gross', 'production_budget']]
# Out:
#                             worldwide_gross  production_budget
# movie
# #Horror                                   0            1500000
# 10 Cloverfield Lane               108286422            5000000
# 10 Days in a Madhouse                 14616           12000000
# 12 Strong                          71118378           35000000
# 12 Years a Slave                  181025343           20000000
# ...                                     ...                ...
# Zookeeper                         170805525           80000000
# Zoolander 2                        55348693           50000000
# Zoom                               12506188           35000000
# Zootopia                         1019429616          150000000
# xXx: Return of Xander Cage        345033359           85000000
#
# [1788 rows x 2 columns]

# %% [markdown]
# ##### Manipulating popularity of the movies

# %%
#the "popularity" column of float values is rounded to 3 decimal places (significant figures)
df_final = df_merged_movie.round(decimals=3)
df_final['popularity'].head(10)
# Out:
# movie
# #Horror                   6.099
# 10 Cloverfield Lane      17.892
# 10 Days in a Madhouse     0.955
# 12 Strong                13.183
# 12 Years a Slave         16.493
# 127 Hours                11.435
# 13 Sins                  10.899
# 1982                      0.600
# 2 Guns                   14.800
# 21 Jump Street           14.836
# Name: popularity, dtype: float64

# %% [markdown]
# <b>Adding "Return On Investment" data AS 'ROI'</b><br>

# %%
df_merged_movie['ROI'] = df_merged_movie['worldwide_gross'] - df_merged_movie['production_budget']
df_merged_movie.head()
# Out:
#                       original_language  popularity  vote_average  vote_count  \
# movie
# #Horror                              de       6.099           3.3         102
# 10 Cloverfield Lane                  en      17.892           6.9        4629
# 10 Days in a Madhouse                en       0.955           5.4           7
# 12 Strong                            en      13.183           5.6        1312
# 12 Years a Slave                     en      16.493           7.9        6631
#
#                        release_date  production_budget  worldwide_gross  \
# movie
# #Horror                Nov 20, 2015            1500000                0
# 10 Cloverfield Lane    Mar 11, 2016            5000000        108286422
# 10 Days in a Madhouse  Nov 11, 2015           12000000            14616
# 12 Strong              Jan 19, 2018           35000000         71118378
# 12 Years a Slave       Oct 18, 2013           20000000        181025343
#
#                       genres  release_month        ROI
# movie
# #Horror                  mix             11   -1500000
# 10 Cloverfield Lane      mix              3  103286422
# 10 Days in a Madhouse  Drama             11  -11985384
# 12 Strong                mix              1   36118378
# 12 Years a Slave         mix             10  161025343

# %% [markdown]
# ### <b>Data Visualization</b><br>
# From here, we use the final dataframe <b>"df_final"</b> to conduct our analysis and discover insights.<br>
# <br>
# <b>Steps:</b><br>
# <br>
# <b>Visualization 1: budget vs. ROI (Revenue minus budget) </b><br>
# We already created a new column for ROI.<br>
# We will create scatterplot with "production_budget" on x-axis, and "worldwide_gross" on y-axis.<br>
#
# <b>Visualization 2: release month vs. average revenue </b><br>
# We already created a new column for "release_month".<br>
# We will find the mean of "worldwide_gross" for each "release_month".<br>
# Produce lineplot with "release_month" on x-axis, and "worldwide_gross" (averages) on y-axis.<br>
#
# <b>Visualization 3: average rating vs. revenue </b><br>
# We want to see how ratings may impact revenue. The problem is: some movies have high ratings, with a very low vote count.<br>
# To fix this, we need to create new dataframe that only provides movies with an "average_vote" when "vote_count" is >= 1000.<br>
# Produce scatterplot with "average_vote" (where "vote_count" >= 1000) on x-axis, and "worldwide_gross" on y-axis.<br>
#
# <b>Visualization 4: genres vs. average revenue </b><br>
# We already created a new datatype in "genres" called "mix" if a movie has more than 1 genre associated with it.<br>
# Need the mean of "worldwide_gross" for each genre.<br>
# Bar plot with "genres" on x-axis, and "worldwide_gross" (averages) on y-axis.

# %% [markdown]
# ### Visualization 1
# Q1 What is the best/ worst movie in terms of ROI

# %%
# Lets find the max ROI
df_merged_movie['ROI'].max()
# Out:
# 2351345279

# %%
# finding row with max ROI to find movie title
df_merged_movie.loc[df_merged_movie['ROI'] == 2351345279]
# Out:
#        original_language  popularity  vote_average  vote_count  release_date  \
# movie
# Avatar                en      26.526           7.4       18676  Dec 18, 2009
#
#         production_budget  worldwide_gross  genres  release_month         ROI
# movie
# Avatar          425000000       2776345279  Horror             12  2351345279

# %%
df_merged_movie['ROI'].min()
# Out:
# -110450242

# %%
# finding row with min ROI to find movie title
df_merged_movie.loc[df_merged_movie['ROI'] == -110450242]
# Out:
#                 original_language  popularity  vote_average  vote_count  \
# movie
# Mars Needs Moms                en       8.852           5.7         299
#
#                  release_date  production_budget  worldwide_gross genres  \
# movie
# Mars Needs Moms  Mar 11, 2011          150000000         39549758    mix
#
#                  release_month        ROI
# movie
# Mars Needs Moms              3 -110450242

# %%
df_ROI_sorted = df_merged_movie['ROI'].sort_values(ascending=True)
df_ROI_sorted[917]
# Out:
# 15085560

# %%
df_merged_movie.loc[df_merged_movie['ROI'] == 15085560]
# Out:
#                     original_language  popularity  vote_average  vote_count  \
# movie
# Sorry to Bother You                en      15.887           6.9         481
#
#                     release_date  production_budget  worldwide_gross genres  \
# movie
# Sorry to Bother You  Jul 6, 2018            3200000         18285560    mix
#
#                      release_month       ROI
# movie
# Sorry to Bother You              7  15085560

# %% [markdown]
# <b>Graph "Budget" vs. "Return On Investment."</b><br>
# Show movies that had a net loss in BLUE, and a net gain in RED.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
x = df_merged_movie["production_budget"]
y = df_merged_movie["ROI"]
df = pd.DataFrame({'x': df_merged_movie["production_budget"], 'y': df_merged_movie["ROI"]})
plt.xlabel('Budget (In Millions Of U.S. Dollars)', fontsize = 20 , weight ='bold')
plt.ylabel('Return On Investment (In Billions Of U.S. Dollars) ', fontsize = 20, weight ='bold')
# plt.title('ROI Vs Budget', fontsize = 17 , weight='bold')
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)
ax.scatter(df.x, df.y, c=np.sign(df.y), cmap="coolwarm")
plt.show()

# %% [markdown]
# #### Visualization 2

# %%
month_average = df_merged_movie[['release_month', 'worldwide_gross']]
month_average_grouped = month_average.groupby('release_month', as_index=False).mean()
month_average_grouped
# Out:
#     release_month  worldwide_gross
# 0               1     6.762834e+07
# 1               2     1.043053e+08
# 2               3     1.112980e+08
# 3               4     9.452846e+07
# 4               5     1.925894e+08
# 5               6     2.141114e+08
# 6               7     1.680255e+08
# 7               8     7.555530e+07
# 8               9     6.199132e+07
# 9              10     7.033294e+07
# 10             11     1.730449e+08
# 11             12     1.285844e+08

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,10)

ax = sns.lineplot(x="release_month", y="worldwide_gross", marker="o", ci=0, markersize=15, data=month_average_grouped)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter(1))
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.ylabel('Average Movie Gross Revenue (In Millions Of U.S. Dollars)', fontsize=15)
plt.xlabel('Movie Release Month', fontsize=15)
sns.set(style='whitegrid', font_scale=1.2)
plt.show()

# %% [markdown]
# #### Visualization 3
# Exploring 'vote_count','vote_average' and 'popularity'
#
# We want to feel a correlation of these mentioned above with worldwide_gross

# %%
#scatterplot of vote_count vs. worldwide_gross
fig, ax = plt.subplots()
fig.set_size_inches(18,12)

ax = sns.scatterplot(x="vote_count", y="worldwide_gross", marker="o", ci=68, data=df_merged_movie)
ax.xaxis.set_major_locator(ticker.MultipleLocator(2000))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.set(xlabel='Number Of Votes', ylabel='Movie Gross Revenue (In Hundreds Of Millions Of U.S. Dollars)')
sns.set(style='whitegrid', font_scale=1.5)
plt.show()

# %% [markdown]
# #### Observation
# There is a correlation between number of votes and gross revenue

# %%
#scatterplot of vote_average vs. worldwide_gross
fig, ax = plt.subplots()
fig.set_size_inches(60,12)

ax = sns.barplot(x="vote_average", y="worldwide_gross", ci=None, data=df_merged_movie)
ax.set(xlabel='Average Movie Rating (1-10)', ylabel='Movie Gross Revenue (In Hundred Millions Of U.S. Dollars)')
sns.set(style='darkgrid', font_scale=2)
plt.show()

# %% [markdown]
# #### Movie rating

# %%
#scatterplot of vote_count vs. vote_average
fig, ax = plt.subplots()
fig.set_size_inches(8,12)

ax = sns.scatterplot(x="vote_average", y="vote_count", marker="o", ci=68, data=df_merged_movie)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.yaxis.set_major_locator(ticker.MultipleLocator(1000))
ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
ax.set(xlabel='Average Movie Rating (1-10)', ylabel='Number Of Votes')
sns.set(style='whitegrid', font_scale=1.2)
plt.show()

# %% [markdown]
# A  lot of movies have ratings below 1000
#
# Let's only consider movies that have only 1000+ votes, on the "vote_average" vs. "worldwide_gross" graph.<br>
# Let's round "vote_average" to the nearest whole number, to decrease the number of bars in the graph and simplify the findings.

# %%
votes_vs_gross = df_merged_movie[['vote_count', 'vote_average', 'worldwide_gross']]
votes_vs_gross_1000 = votes_vs_gross.loc[votes_vs_gross['vote_count'] >= 1000]
votes_vs_gross_1000 = votes_vs_gross_1000.round(0)
votes_vs_gross_1000
# Out:
#                             vote_count  vote_average  worldwide_gross
# movie
# 10 Cloverfield Lane               4629           7.0        108286422
# 12 Strong                         1312           6.0         71118378
# 12 Years a Slave                  6631           8.0        181025343
# 127 Hours                         4469           7.0         60217171
# 2 Guns                            2368           6.0        132493015
# ...                                ...           ...              ...
# Youth                             1098           7.0         24001573
# Zero Dark Thirty                  2553           7.0        134612435
# Zoolander 2                       1374           5.0         55348693
# Zootopia                          9977           8.0       1019429616
# xXx: Return of Xander Cage        2452           6.0        345033359
#
# [730 rows x 3 columns]

# %% [markdown]
# Getting average
#
# We need average revenue for all rounded "vote_average" values - so we need a new dataframe.

# %%
votes_vs_gross_1000_grouped = votes_vs_gross_1000.groupby('vote_average', as_index=False).mean()
votes_vs_gross_1000_grouped
# Out:
#    vote_average   vote_count  worldwide_gross
# 0           4.0  2097.666667     1.165111e+08
# 1           5.0  2095.552632     1.377204e+08
# 2           6.0  2761.542056     2.159237e+08
# 3           7.0  4184.656028     2.595058e+08
# 4           8.0  7050.825581     3.836826e+08

# %%
#scatterplot of vote_average, when vote_count is > 1000, vs. worldwide_gross
fig, ax = plt.subplots()
fig.set_size_inches(12,12)

ax = sns.barplot(x="vote_average", y="worldwide_gross", ci=None, data=votes_vs_gross_1000_grouped)
sns.set(style='whitegrid', font_scale=1.2)
sns.set_palette("Reds")
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.ylabel('Average Movie Gross Revenue (In Millions Of U.S. Dollars)', fontsize=20)
plt.xlabel('Average Movie Rating (1-10)', fontsize=20)
plt.show()

# %% [markdown]
# ### Visualization 4
# Sorting genres

# %%
genres_average = df_merged_movie[['genres', 'worldwide_gross']]
genres_average_grouped = genres_average.groupby('genres', as_index=False).mean()
genres_average_grouped_sorted = genres_average_grouped.sort_values(by='worldwide_gross', ascending=True)
genres_average_grouped_sorted
# Out:
#          genres  worldwide_gross
# 10        Music     0.000000e+00
# 15      Western     6.250196e+06
# 12      Mystery     7.000000e+06
# 8       Fantasy     1.403222e+07
# 2     Animation     2.517846e+07
# 11      Musical     2.550942e+07
# 7        Family     2.958435e+07
# 6         Drama     3.469134e+07
# 5   Documentary     4.662250e+07
# 3        Comedy     5.732658e+07
# 0        Action     7.014611e+07
# 14     Thriller     7.390183e+07
# 4         Crime     9.962487e+07
# 9        Horror     1.124098e+08
# 16          mix     1.340937e+08
# 13       Sci-Fi     4.759928e+08
# 1     Adventure     4.984382e+08

# %%
genres_average_grouped_sorted = genres_average_grouped_sorted.drop(genres_average_grouped_sorted.index[:7])
genres_average_grouped_sorted
# Out:
#          genres  worldwide_gross
# 6         Drama     3.469134e+07
# 5   Documentary     4.662250e+07
# 3        Comedy     5.732658e+07
# 0        Action     7.014611e+07
# 14     Thriller     7.390183e+07
# 4         Crime     9.962487e+07
# 9        Horror     1.124098e+08
# 16          mix     1.340937e+08
# 13       Sci-Fi     4.759928e+08
# 1     Adventure     4.984382e+08

# %%
#scatterplot of genres vs. worldwide_gross (average)
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True)
pal = sns.color_palette("Greens_d", len(genres_average_grouped_sorted))
fig, ax = plt.subplots()
fig.set_size_inches(30,15)
ax = sns.barplot(x="genres", y="worldwide_gross", ci=None, palette=np.array(pal[::-1]),data=genres_average_grouped_sorted)
#ax.set(xlabel='Movie Genre', ylabel='Average Movie Gross Revenue (U.S. Dollars)')
plt.xlabel('Movie Genres', fontsize=25, weight = 'bold')
plt.ylabel('Average Movie Gross Revenue (In Millions Of U.S. Dollars)', fontsize=25, weight = 'bold')
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.tick_params(axis='both', which='major', labelsize=20)
#sns.set_style('darkgrid')
plt.show()
